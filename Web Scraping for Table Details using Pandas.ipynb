# %%
import pandas as pd

eu = pd.read_html("http://en.wikipedia.org/wiki/Member_state_of_the_European_Union", attrs = {"class":"wikitable sortable"}, header = 0)

# %%
print eu
# Out:
# [         Country name                                        Native name  \
# 0             Austria                                         Österreich
# 1             Belgium                              BelgiëBelgiqueBelgien
# 2            Bulgaria                               България (Bǎlgariya)
# 3             Croatia                                           Hrvatska
# 4              Cyprus                              Κύπρος (Kípros)Kıbrıs
# 5      Czech Republic                                              Česko
# 6             Denmark                                            Danmark
# 7             Estonia                                              Eesti
# 8             Finland                                              Suomi
# 9              France                                             France
# 10            Germany                                        Deutschland
# 11             Greece                                    Ελλάδα (Elláda)
# ...

# %%
eu[0]
# Out:
#          Country name                                        Native name  \
# 0             Austria                                         Österreich
# 1             Belgium                              BelgiëBelgiqueBelgien
# 2            Bulgaria                               България (Bǎlgariya)
# 3             Croatia                                           Hrvatska
# 4              Cyprus                              Κύπρος (Kípros)Kıbrıs
# 5      Czech Republic                                              Česko
# 6             Denmark                                            Danmark
# 7             Estonia                                              Eesti
# 8             Finland                                              Suomi
# 9              France                                             France
# 10            Germany                                        Deutschland
# 11             Greece                                    Ελλάδα (Elláda)
# ...

# %%
eu_df = pd.DataFrame(eu[0])

# %%
eu_df
# Out:
#          Country name                                        Native name  \
# 0             Austria                                         Österreich
# 1             Belgium                              BelgiëBelgiqueBelgien
# 2            Bulgaria                               България (Bǎlgariya)
# 3             Croatia                                           Hrvatska
# 4              Cyprus                              Κύπρος (Kípros)Kıbrıs
# 5      Czech Republic                                              Česko
# 6             Denmark                                            Danmark
# 7             Estonia                                              Eesti
# 8             Finland                                              Suomi
# 9              France                                             France
# 10            Germany                                        Deutschland
# 11             Greece                                    Ελλάδα (Elláda)
# ...

# %%
eu_df['Capital'][3]
# Out:
# 'Zagreb'
