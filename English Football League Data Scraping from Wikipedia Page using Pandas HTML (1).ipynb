# %%
import pandas as pd
from pandas import Series,DataFrame

epl = pd.read_html("https://en.wikipedia.org/wiki/List_of_English_football_champions", attrs = {'class':'wikitable sortable'}, header = 0)

print epl
# Out:
# [      Year Champions(number of titles)         Runners-up  \
# 0  1888–89        Preston North End[1]        Aston Villa
# 1  1889–90       Preston North End (2)            Everton
# 2  1890–91                     Everton  Preston North End
# 3  1891–92                  Sunderland  Preston North End
#
#                Third place                  Leading goalscorer  Goals
# 0  Wolverhampton Wanderers    John Goodall (Preston North End)     21
# 1         Blackburn Rovers      Jimmy Ross (Preston North End)     24
# 2             Notts County  Jack Southworth (Blackburn Rovers)     26
# 3         Bolton Wanderers          John Campbell (Sunderland)     32  ,                Year                    Champions(number of titles)  \
# 0           1892–93                                 Sunderland (2)
# 1           1893–94                                    Aston Villa
# 2           1894–95                                 Sunderland (3)
# ...

# %%
type(epl)

# %%
epl[0]

# %%
epl[1]

# %%
epl[3]

# %%
football_league = pd.DataFrame(epl[1])

# %%
football_league

# %%
epl[2]

# %%
epl_data = DataFrame(epl[2])

# %%
epl_data
# Out:
#          Year Champions (number of titles)         Runners-up  \
# 0     1992–93        Manchester United (8)        Aston Villa
# 1     1993–94        Manchester United (9)   Blackburn Rovers
# 2     1994–95         Blackburn Rovers (3)  Manchester United
# 3     1995–96       Manchester United (10)   Newcastle United
# 4     1996–97       Manchester United (11)   Newcastle United
# 5     1997–98                 Arsenal (11)  Manchester United
# 6     1998–99    Manchester United[7] (12)            Arsenal
# 7   1999–2000       Manchester United (13)            Arsenal
# 8     2000–01       Manchester United (14)            Arsenal
# 9     2001–02                 Arsenal (12)          Liverpool
# 10    2002–03       Manchester United (15)            Arsenal
# 11    2003–04              Arsenal[1] (13)            Chelsea
# 12    2004–05               Chelsea[4] (2)            Arsenal
# 13    2005–06                  Chelsea (3)  Manchester United
# ...

# %%
champs = epl[3]

print champs
# Out:
#                        Club  Winners  Runners-up  \
# 0         Manchester United       20          16
# 1                 Liverpool       18          13
# 2                   Arsenal       13           9
# 3                   Everton        9           7
# 4               Aston Villa        7          10
# 5                Sunderland        6           5
# 6                   Chelsea        6           4
# 7           Manchester City        5           5
# 8          Newcastle United        4           2
# 9       Sheffield Wednesday        4           1
# 10             Leeds United        3           5
# 11  Wolverhampton Wanderers        3           5
# 12        Huddersfield Town        3           3
# 13         Blackburn Rovers        3           1
# 14        Preston North End        2           6
# 15        Tottenham Hotspur        2           5
# 16             Derby County        2           3
# 17                  Burnley        2           2
# ...

# %%
champs.to_csv(r"C:\Users\Sarath\Desktop\EPL_No of Titles.csv",na_rep = 'None',encoding = "cp1252", index = None)

# %%
# https://stackoverflow.com/questions/5387895/unicodeencodeerror-ascii-codec-cant-encode-character-u-u2013-in-position-3
