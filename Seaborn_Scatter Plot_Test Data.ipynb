# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')

sns.regplot(x=df["sepal_length"], y = df["sepal_width"])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx')

df = pd.DataFrame(data)

df.describe()
# Out:
#        Entry No.    User ID        Age  No of years worked in the building  \
# count  15.000000  15.000000  15.000000                           15.000000
# mean    8.000000   3.800000  31.266667                            3.200000
# std     4.472136   1.897367   7.085868                            2.305273
# min     1.000000   1.000000  18.000000                            0.500000
# 25%     4.500000   2.000000  27.000000                            1.500000
# 50%     8.000000   4.000000  31.000000                            2.000000
# 75%    11.500000   5.500000  35.000000                            4.000000
# max    15.000000   6.000000  40.000000                            7.000000
#
#        Average Number of Hours spent at the work space  \
# count                                        15.000000
# mean                                          6.666667
# std                                           1.175139
# min                                           5.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx')

df = pd.DataFrame(data)

sns.regplot(x = df['Weather Data Temperature'], y = df['Weather Data Humidity'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx')

df = pd.DataFrame(data)

sns.regplot(x = df['Weather Data Temperature'], y = df['Thermal Comfort related complaint'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx', index = None)

# print data.head()

# df_personal = data.iloc[:,0:8]

# df_personal.head()

# df = pd.DataFrame(data)

sns_plot = sns.pairplot(data, kind = "scatter", hue = 'Gender', vars = ['Age', 'No of years worked in the building','Average Number of Hours spent at the work space','Space Related Complaint'], height = 4 )

#sns_plot.savefig(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\Output.png')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx', index = None)

print data.columns

# sns_plot = sns.pairplot(data, kind = "reg", hue = 'Gender', vars = ['Age', 'No of years worked in the building','Average Number of Hours spent at the work space','Space Related Complaint'], height = 4 )

sns_plot = sns.pairplot(data, kind = "reg", height = 4, palette = 'colorblind')

sns_plot.savefig(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\Output.png')

plt.show()
# Out:
# Index([u'Entry No.', u'Time of Entry', u'Date', u'User ID', u'Gender', u'Age',
#        u'No of years worked in the building',
#        u'Average Number of Hours spent at the work space',
#        u'Space Related Complaint', u'Lighting Related Complaint',
#        u'Natural Lighting Complaint', u'Artificial Lighting Complaint',
#        u'Complaint for Both types of lighting',
#        u'Thermal Comfort related complaint', u'Air Quality Related Complaint',
#        u'Acoustic Comfort Related Complaint', u'Measured Room Temperature',
#        u'Measured Humidity', u'Measured Lux Level',
#        u'Weather Data Temperature', u'Weather Data Cloud Cover',
#        u'Weather Data Humidity'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx', index = None)

print data.columns

# sns_plot = sns.pairplot(data, kind = "reg", hue = 'Gender', vars = ['Age', 'No of years worked in the building','Average Number of Hours spent at the work space','Space Related Complaint'], height = 4 )

sns_plot = sns.pairplot(data, kind = "reg", height = 4, x_vars = ['Age','No of years worked in the building','Average Number of Hours spent at the work space','Measured Room Temperature','Measured Humidity','Measured Lux Level','Weather Data Temperature'],y_vars = ['Age','No of years worked in the building','Average Number of Hours spent at the work space','Thermal Comfort related complaint','Air Quality Related Complaint','Acoustic Comfort Related Complaint'], hue = 'Gender' )

sns_plot.savefig(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\Output.png')

plt.show()
# Out:
# Index([u'Entry No.', u'Time of Entry', u'Date', u'User ID', u'Gender', u'Age',
#        u'No of years worked in the building',
#        u'Average Number of Hours spent at the work space',
#        u'Space Related Complaint', u'Lighting Related Complaint',
#        u'Natural Lighting Complaint', u'Artificial Lighting Complaint',
#        u'Complaint for Both types of lighting',
#        u'Thermal Comfort related complaint', u'Air Quality Related Complaint',
#        u'Acoustic Comfort Related Complaint', u'Measured Room Temperature',
#        u'Measured Humidity', u'Measured Lux Level',
#        u'Weather Data Temperature', u'Weather Data Cloud Cover',
#        u'Weather Data Humidity'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\# Test Data Set.xlsx', index = None)

# print data.columns

# sns_plot = sns.pairplot(data, kind = "reg", hue = 'Gender', vars = ['Age', 'No of years worked in the building','Average Number of Hours spent at the work space','Space Related Complaint'], height = 4 )

sns_plot = sns.pairplot(data, kind = "scatter", height = 4, x_vars = ['Age','No of years worked in the building','Average Number of Hours spent at the work space','Measured Room Temperature','Measured Humidity','Measured Lux Level','Weather Data Temperature'],y_vars = ['Age','No of years worked in the building','Average Number of Hours spent at the work space','Space Related Complaint','Lighting Related Complaint','Thermal Comfort related complaint','Air Quality Related Complaint','Acoustic Comfort Related Complaint'] )

# sns_plot.savefig(r'C:\Users\Sarath Sasidharan\Desktop\R_Python\Output.png')

plt.show()
